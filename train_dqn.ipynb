# %%
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
import matplotlib.pyplot as plt
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3 import PPO,DDPG,DQN
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback
import gym
import numpy as np
import time
from stable_baselines3.common.callbacks import EvalCallback
import env
env = env.ElectricVehicleEnv()
#vec_env = make_vec_env(env, n_envs=4)
check_env(env)
env = DummyVecEnv([lambda: env])

# %%
import numpy as np
import gymnasium as gym

from stable_baselines3 import DQN,A2C
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.logger import configure



# 设置日志目录和TensorBoard日志
log_dir = "log"
# 配置logger，使其在log目录下存储TensorBoard日志
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# 创建DQN模型，并设置日志记录
model = A2C('MlpPolicy', env, verbose=1)

# 将新配置的logger应用于模型
model.set_logger(new_logger)

# 训练模型，并将TensorBoard日志存储到log目录中
model.learn(total_timesteps=10000)

# 保存模型
model.save("dqn_electric_vehicle")

# 加载模型（如果需要）
# model = DQN.load("dqn_electric_vehicle")

# 评估模型
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)

print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")

# 测试训练好的模型
obs = env.reset()
for i in range(100):
    action = model.predict(obs, deterministic=True)[0]
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
        obs, info  = env.reset()
# Out:
# Logging to log
# Using cuda device
# ------------------------------------
# | time/                 |          |
# |    fps                | 110      |
# |    iterations         | 100      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -3.56    |
# |    explained_variance | 0.000161 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -312     |
# |    value_loss         | 8.65e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 174       |
# |    iterations         | 200       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -3.37     |
# |    explained_variance | -0.000198 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -308      |
# |    value_loss         | 6.6e+03   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 218      |
# |    iterations         | 300      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -3.39    |
# |    explained_variance | 8.17e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -5.05    |
# |    value_loss         | 855      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 400       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -3.61     |
# |    explained_variance | -2.79e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -112      |
# |    value_loss         | 1.86e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -3.66    |
# |    explained_variance | 0.00012  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -195     |
# |    value_loss         | 8.44e+03 |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 23
#      20 model.set_logger(new_logger)
#      22 # 训练模型，并将TensorBoard日志存储到log目录中
# ---> 23 model.learn(total_timesteps=10000)
#      25 # 保存模型
#      26 model.save("dqn_electric_vehicle")
#
# File C:\ProgramData\anaconda3\envs\UAV\lib\site-packages\stable_baselines3\a2c\a2c.py:201, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     192 def learn(
#     193     self: SelfA2C,
#     194     total_timesteps: int,
#    (...)
#     199     progress_bar: bool = False,
#     200 ) -> SelfA2C:
# --> 201     return super().learn(
#     202         total_timesteps=total_timesteps,
#     203         callback=callback,
#     204         log_interval=log_interval,
#     205         tb_log_name=tb_log_name,
#     206         reset_num_timesteps=reset_num_timesteps,
#     207         progress_bar=progress_bar,
#     208     )
#
# File C:\ProgramData\anaconda3\envs\UAV\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File C:\ProgramData\anaconda3\envs\UAV\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:199, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     196 self.num_timesteps += env.num_envs
#     198 # Give access to local variables
# --> 199 callback.update_locals(locals())
#     200 if not callback.on_step():
#     201     return False
#
# File C:\ProgramData\anaconda3\envs\UAV\lib\site-packages\stable_baselines3\common\callbacks.py:134, in BaseCallback.update_locals(self, locals_)
#     128 def update_locals(self, locals_: Dict[str, Any]) -> None:
#     129     """
#     130     Update the references to the local variables.
#     131
#     132     :param locals_: the local variables during rollout collection
#     133     """
# --> 134     self.locals.update(locals_)
#     135     self.update_child_locals(locals_)
#
# KeyboardInterrupt:
