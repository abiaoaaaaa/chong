# %%
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
import matplotlib.pyplot as plt
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3 import PPO,DDPG,DQN
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback
import gym
import numpy as np
import time
from stable_baselines3.common.callbacks import EvalCallback
import env
env = env.ElectricVehicleEnv()
#vec_env = make_vec_env(env, n_envs=4)
check_env(env)
env = DummyVecEnv([lambda: env])

# %%
import numpy as np
import gymnasium as gym

from stable_baselines3 import DQN,A2C
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.logger import configure



# 设置日志目录和TensorBoard日志
log_dir = "log"
# 配置logger，使其在log目录下存储TensorBoard日志
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# 创建DQN模型，并设置日志记录
model = A2C('MlpPolicy', env, verbose=1)

# 将新配置的logger应用于模型
model.set_logger(new_logger)

# 训练模型，并将TensorBoard日志存储到log目录中
model.learn(total_timesteps=100000)

# 保存模型
model.save("dqn_electric_vehicle")

# 加载模型（如果需要）
# model = DQN.load("dqn_electric_vehicle")

# 评估模型
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)

print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")

# 测试训练好的模型
obs = env.reset()
for i in range(100):
    action = model.predict(obs, deterministic=True)[0]
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
        obs = env.reset()
# Out:
# Logging to log
# Using cuda device
# ------------------------------------
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.000833 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.11e+03 |
# |    value_loss         | 9.07e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.651   |
# |    explained_variance | 0.000522 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.01e+03 |
# |    value_loss         | 8.78e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.476   |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 65.5     |
# |    value_loss         | 9.26e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.417   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 57.1     |
# |    value_loss         | 9.17e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 349       |
# |    iterations         | 500       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -0.371    |
# |    explained_variance | -2.86e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 1.09e+03  |
# |    value_loss         | 9.06e+05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 600      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.122   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 13.6     |
# |    value_loss         | 8.99e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 700      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.09    |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 9.54     |
# |    value_loss         | 8.91e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 800      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.071   |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 7.29     |
# |    value_loss         | 8.82e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 900      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.0329  |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 3.06     |
# |    value_loss         | 8.74e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 387      |
# |    iterations         | 1000     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.0251  |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 2.25     |
# |    value_loss         | 8.65e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 391      |
# |    iterations         | 1100     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.0149  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.25     |
# |    value_loss         | 8.57e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 397      |
# |    iterations         | 1200     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.00915 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.729    |
# |    value_loss         | 8.48e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 401      |
# |    iterations         | 1300     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.00575 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.436    |
# |    value_loss         | 8.4e+05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 402      |
# |    iterations         | 1400     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.00367 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.266    |
# |    value_loss         | 8.32e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 402      |
# |    iterations         | 1500     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.00238 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.164    |
# |    value_loss         | 8.23e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 397      |
# |    iterations         | 1600     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.00156 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 8.15e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 397      |
# |    iterations         | 1700     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.00104 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.0668   |
# |    value_loss         | 8.07e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 398       |
# |    iterations         | 1800      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.000704 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.0435    |
# |    value_loss         | 7.99e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 397       |
# |    iterations         | 1900      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.000489 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.0288    |
# |    value_loss         | 7.91e+05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 399      |
# |    iterations         | 2000     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.00035 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0202   |
# |    value_loss         | 7.83e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 400       |
# |    iterations         | 2100      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.000258 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 0.0143    |
# |    value_loss         | 7.74e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 401       |
# |    iterations         | 2200      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.000198 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 0.0109    |
# |    value_loss         | 7.67e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 401       |
# |    iterations         | 2300      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.000157 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.00831   |
# |    value_loss         | 7.59e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 402       |
# |    iterations         | 2400      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.000128 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 0.00661   |
# |    value_loss         | 7.51e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 403       |
# |    iterations         | 2500      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 0.00575   |
# |    value_loss         | 7.43e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 2600      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -9.32e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 0.00491   |
# |    value_loss         | 7.35e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 2700      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -8.18e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | 0.00407   |
# |    value_loss         | 7.27e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 2800      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -7.25e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 0.00324   |
# |    value_loss         | 7.19e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 2900      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -6.59e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 0.00322   |
# |    value_loss         | 7.12e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 3000      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -6.01e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.0032    |
# |    value_loss         | 7.04e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 409       |
# |    iterations         | 3100      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -5.43e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 0.00239   |
# |    value_loss         | 6.96e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 3200      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -5.05e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | 0.00237   |
# |    value_loss         | 6.89e+05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 411      |
# |    iterations         | 3300     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -4.7e-05 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00236  |
# |    value_loss         | 6.81e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 3400      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -4.37e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 0.00235   |
# |    value_loss         | 6.74e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 3500      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -4.02e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 0.00156   |
# |    value_loss         | 6.66e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 3600      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -3.82e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 0.00155   |
# |    value_loss         | 6.59e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 3700      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -3.63e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 0.00154   |
# |    value_loss         | 6.52e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 3800      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -3.45e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 0.00153   |
# |    value_loss         | 6.44e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 3900      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -3.28e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 0.00152   |
# |    value_loss         | 6.37e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 4000      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -3.12e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 0.00151   |
# |    value_loss         | 6.3e+05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 4100      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -2.97e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | 0.00151   |
# |    value_loss         | 6.23e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 4200      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -2.83e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | 0.0015    |
# |    value_loss         | 6.15e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 4300      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -2.62e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | 0.000744  |
# |    value_loss         | 6.08e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 4400      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -2.55e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 0.000739  |
# |    value_loss         | 6.01e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 4500      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -2.49e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 0.000735  |
# |    value_loss         | 5.94e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 419       |
# |    iterations         | 4600      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -2.42e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 0.000731  |
# |    value_loss         | 5.87e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 4700      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -2.36e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 0.000726  |
# |    value_loss         | 5.8e+05   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 420      |
# |    iterations         | 4800     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -2.3e-05 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.000722 |
# |    value_loss         | 5.73e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 421       |
# |    iterations         | 4900      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -2.25e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | 0.000718  |
# |    value_loss         | 5.66e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 421       |
# |    iterations         | 5000      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -2.19e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | 0.000713  |
# |    value_loss         | 5.6e+05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 421       |
# |    iterations         | 5100      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -2.14e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 0.000709  |
# |    value_loss         | 5.53e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 421       |
# |    iterations         | 5200      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -2.09e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 0.000705  |
# |    value_loss         | 5.46e+05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 421      |
# |    iterations         | 5300     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -2.1e-05 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.0014   |
# |    value_loss         | 5.39e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 5400      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -1.85e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.33e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 5500      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -1.85e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.26e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 5600      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.84e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.2e+05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 5700      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -1.84e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.13e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 5800      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -1.84e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.07e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 5900      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -1.84e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -0        |
# |    value_loss         | 5e+05     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 421       |
# |    iterations         | 6000      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -1.84e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.94e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 421       |
# |    iterations         | 6100      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -1.84e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.87e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 6200      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -1.83e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.81e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 420       |
# |    iterations         | 6300      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -1.83e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.75e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 419       |
# |    iterations         | 6400      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -1.83e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.68e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 419       |
# |    iterations         | 6500      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -1.83e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.62e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 6600      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -1.83e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.56e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 419       |
# |    iterations         | 6700      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -1.83e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.5e+05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 419       |
# |    iterations         | 6800      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -1.82e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.44e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 419       |
# |    iterations         | 6900      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -1.82e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.38e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 7000      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -1.82e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.32e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 7100      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -1.82e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.26e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 7200      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -1.82e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.2e+05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 7300      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -1.82e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.14e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 7400      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -1.81e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.08e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 7500      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -1.81e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.02e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 7600      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -1.81e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.97e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 7700      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -1.81e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.91e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 7800      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -1.81e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.85e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 7900      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -1.81e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.8e+05   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 416      |
# |    iterations         | 8000     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.8e-05 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | -0       |
# |    value_loss         | 3.74e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 416      |
# |    iterations         | 8100     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -1.8e-05 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -0       |
# |    value_loss         | 3.69e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 416      |
# |    iterations         | 8200     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -1.8e-05 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -0       |
# |    value_loss         | 3.63e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 416      |
# |    iterations         | 8300     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -1.8e-05 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | -0       |
# |    value_loss         | 3.58e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 416      |
# |    iterations         | 8400     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -1.8e-05 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | -0       |
# |    value_loss         | 3.52e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 416      |
# |    iterations         | 8500     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -1.8e-05 |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | -0       |
# |    value_loss         | 3.47e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 8600      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -1.79e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.41e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 8700      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -1.79e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.36e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 8800      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -1.79e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.31e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 8900      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -1.79e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.26e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 9000      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -1.79e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.2e+05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 9100      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -1.79e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# ...
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17100     |
# |    time_elapsed       | 207       |
# |    total_timesteps    | 85500     |
# | train/                |           |
# |    entropy_loss       | -1.67e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17099     |
# |    policy_loss        | -0        |
# |    value_loss         | 3.9e+04   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17200     |
# |    time_elapsed       | 208       |
# |    total_timesteps    | 86000     |
# | train/                |           |
# |    entropy_loss       | -1.67e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17199     |
# |    policy_loss        | -0        |
# |    value_loss         | 3.73e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17300     |
# |    time_elapsed       | 209       |
# |    total_timesteps    | 86500     |
# | train/                |           |
# |    entropy_loss       | -1.67e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17299     |
# |    policy_loss        | -0        |
# |    value_loss         | 3.55e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17400     |
# |    time_elapsed       | 210       |
# |    total_timesteps    | 87000     |
# | train/                |           |
# |    entropy_loss       | -1.67e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17399     |
# |    policy_loss        | -0        |
# |    value_loss         | 3.38e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17500     |
# |    time_elapsed       | 212       |
# |    total_timesteps    | 87500     |
# | train/                |           |
# |    entropy_loss       | -1.67e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17499     |
# |    policy_loss        | -0        |
# |    value_loss         | 3.22e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17600     |
# |    time_elapsed       | 213       |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -1.67e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17599     |
# |    policy_loss        | -0        |
# |    value_loss         | 3.06e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17700     |
# |    time_elapsed       | 214       |
# |    total_timesteps    | 88500     |
# | train/                |           |
# |    entropy_loss       | -1.67e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17699     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.9e+04   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17800     |
# |    time_elapsed       | 215       |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -1.66e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.75e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 17900     |
# |    time_elapsed       | 216       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -1.66e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.6e+04   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18000     |
# |    time_elapsed       | 218       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -1.66e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17999     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.45e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18100     |
# |    time_elapsed       | 219       |
# |    total_timesteps    | 90500     |
# | train/                |           |
# |    entropy_loss       | -1.66e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18099     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.31e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18200     |
# |    time_elapsed       | 220       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -1.66e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.18e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18300     |
# |    time_elapsed       | 221       |
# |    total_timesteps    | 91500     |
# | train/                |           |
# |    entropy_loss       | -1.66e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18299     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.04e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18400     |
# |    time_elapsed       | 222       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -1.66e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18399     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.92e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18500     |
# |    time_elapsed       | 224       |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -1.66e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.79e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18600     |
# |    time_elapsed       | 225       |
# |    total_timesteps    | 93000     |
# | train/                |           |
# |    entropy_loss       | -1.65e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18599     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.67e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18700     |
# |    time_elapsed       | 226       |
# |    total_timesteps    | 93500     |
# | train/                |           |
# |    entropy_loss       | -1.65e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18699     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.56e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18800     |
# |    time_elapsed       | 227       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -1.65e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18799     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.45e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 18900     |
# |    time_elapsed       | 229       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -1.65e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.34e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19000     |
# |    time_elapsed       | 230       |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -1.65e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.23e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19100     |
# |    time_elapsed       | 231       |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | -1.65e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.14e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19200     |
# |    time_elapsed       | 232       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -1.65e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.04e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19300     |
# |    time_elapsed       | 233       |
# |    total_timesteps    | 96500     |
# | train/                |           |
# |    entropy_loss       | -1.65e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19299     |
# |    policy_loss        | -0        |
# |    value_loss         | 9.5e+03   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19400     |
# |    time_elapsed       | 235       |
# |    total_timesteps    | 97000     |
# | train/                |           |
# |    entropy_loss       | -1.64e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19399     |
# |    policy_loss        | -0        |
# |    value_loss         | 8.63e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19500     |
# |    time_elapsed       | 236       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -1.64e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | -0        |
# |    value_loss         | 7.81e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19600     |
# |    time_elapsed       | 237       |
# |    total_timesteps    | 98000     |
# | train/                |           |
# |    entropy_loss       | -1.64e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19599     |
# |    policy_loss        | -0        |
# |    value_loss         | 7.02e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19700     |
# |    time_elapsed       | 238       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -1.64e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -0        |
# |    value_loss         | 6.28e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19800     |
# |    time_elapsed       | 239       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -1.64e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -0        |
# |    value_loss         | 5.58e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 19900     |
# |    time_elapsed       | 241       |
# |    total_timesteps    | 99500     |
# | train/                |           |
# |    entropy_loss       | -1.64e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19899     |
# |    policy_loss        | -0        |
# |    value_loss         | 4.92e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 20000     |
# |    time_elapsed       | 242       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -1.64e-05 |
# |    explained_variance | 1         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -0        |
# |    value_loss         | 4.3e+03   |
# -------------------------------------
# Mean reward: 982.900146484375, Std reward: 0.0

# %%
eval_freq = 500  # 评估频率
eval_callback = EvalCallback(
    env,
    callback_on_new_best=None,
    n_eval_episodes=20,
    best_model_save_path="./best_model/A2C",
    log_path="./logs/A2C",
    eval_freq=eval_freq,
)
log_name = "A2C"
model = A2C("MlpPolicy", env, verbose=0, tensorboard_log="/logs/A2C", device="cuda")
model.learn(
    total_timesteps=100000,
    tb_log_name=log_name,
    callback=[eval_callback]
)
# Out:
# Eval num_timesteps=500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=1000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=1500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=2000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=2500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=3000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=3500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=4000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=4500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=5000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=5500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=6000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=6500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=7000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=7500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=8000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=8500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=9000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=9500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=10000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=10500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=11000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=11500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=12000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=12500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=13000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=13500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=14000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=14500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=15000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=15500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=16000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=16500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=17000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=17500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=18000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=18500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=19000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=19500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=20000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=20500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=21000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=21500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=22000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=22500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=23000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=23500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=24000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=24500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=25000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=25500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=26000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=26500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=27000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=27500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=28000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=28500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=29000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=29500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=30000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=30500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=31000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=31500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=32000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=32500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=33000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=33500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=34000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=34500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=35000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=35500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=36000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=36500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=37000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=37500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=38000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=38500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=39000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=39500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=40000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=40500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=41000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=41500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=42000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=42500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=43000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=43500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=44000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=44500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=45000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=45500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=46000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=46500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=47000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=47500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=48000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=48500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=49000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=49500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=50000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=50500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=51000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=51500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=52000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=52500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=53000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=53500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=54000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=54500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=55000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=55500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=56000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=56500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=57000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=57500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=58000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=58500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=59000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=59500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=60000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=60500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=61000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=61500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=62000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=62500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=63000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=63500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=64000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=64500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=65000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=65500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=66000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=66500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=67000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=67500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=68000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=68500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=69000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=69500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=70000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=70500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=71000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=71500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=72000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=72500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=73000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=73500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=74000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=74500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=75000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=75500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=76000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=76500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=77000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=77500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=78000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=78500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=79000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=79500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=80000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=80500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=81000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=81500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=82000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=82500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=83000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=83500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=84000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=84500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=85000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=85500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=86000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=86500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=87000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=87500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=88000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=88500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=89000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=89500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=90000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=90500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=91000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=91500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=92000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=92500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=93000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=93500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=94000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=94500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=95000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=95500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=96500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=97000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=97500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=98000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=98500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=99000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=99500, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=982.90 +/- 0.00
# Episode length: 1.00 +/- 0.00
